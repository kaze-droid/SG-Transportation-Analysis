# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %% [markdown]
# ## Cleaning for Objective
# ### Dataset 1 (Bus Demand)
# url: https://datamall.lta.gov.sg/content/datamall/en/dynamic-data.html
#
# Used: Passenger Volume By Bus Stops (from Oct22-Dec22)

# %%
df1 = pd.read_csv('./datasrc/transport_node_bus_202210.csv')
df2 = pd.read_csv('./datasrc/transport_node_bus_202211.csv')
df3 = pd.read_csv('./datasrc/transport_node_bus_202212.csv')

# %%
print(f"{'10-2022':*^28}")
print(df1.isnull().sum())
print(f"{'11-2022':*^28}")
print(df2.isnull().sum())
print(f"{'12-2022':*^28}")
print(df3.isnull().sum())
# Out:
# **********10-2022***********
# YEAR_MONTH              0
# DAY_TYPE                0
# TIME_PER_HOUR           0
# PT_TYPE                 0
# PT_CODE                 0
# TOTAL_TAP_IN_VOLUME     0
# TOTAL_TAP_OUT_VOLUME    0
# dtype: int64
# **********11-2022***********
# YEAR_MONTH              0
# DAY_TYPE                0
# TIME_PER_HOUR           0
# PT_TYPE                 0
# PT_CODE                 0
# TOTAL_TAP_IN_VOLUME     0
# TOTAL_TAP_OUT_VOLUME    0
# dtype: int64
# **********12-2022***********
# YEAR_MONTH              0
# DAY_TYPE                0
# TIME_PER_HOUR           0
# PT_TYPE                 0
# PT_CODE                 0
# TOTAL_TAP_IN_VOLUME     0
# TOTAL_TAP_OUT_VOLUME    0
# dtype: int64

# %%
# Merge all dataframes into one (row-wise)
df = pd.concat([df1, df2, df3], ignore_index=True, axis=0)
print(df.isnull().sum())
# Out:
# YEAR_MONTH              0
# DAY_TYPE                0
# TIME_PER_HOUR           0
# PT_TYPE                 0
# PT_CODE                 0
# TOTAL_TAP_IN_VOLUME     0
# TOTAL_TAP_OUT_VOLUME    0
# dtype: int64

# %%
# Get rid of the outliers for TOTAL_TAP_IN_VOLUME and TOTAL_TAP_OUT_VOLUME
from scipy import stats
df = df[(np.abs(stats.zscore(df['TOTAL_TAP_IN_VOLUME'])) < 3)]
df = df[(np.abs(stats.zscore(df['TOTAL_TAP_OUT_VOLUME'])) < 3)]
df.describe()
# Out:
#        TIME_PER_HOUR        PT_CODE  TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME
# count  575185.000000  575185.000000        575185.000000         575185.000000
# mean       13.279747   48941.690018           285.352535            267.458927
# std         6.158887   25457.164274           486.533475            401.018905
# min         0.000000    1012.000000             0.000000              0.000000
# 25%         9.000000   25421.000000            20.000000             22.000000
# 50%        14.000000   50038.000000            99.000000            106.000000
# 75%        18.000000   67141.000000           328.000000            330.000000
# max        23.000000   99189.000000          4550.000000           2518.000000

# %%
# Get the mean across the three months to get monthly tap in and tap out
df = df.groupby(["PT_CODE","DAY_TYPE","TIME_PER_HOUR"]).mean().round().astype("int").sort_index()
df.rename(columns={"TOTAL_TAP_IN_VOLUME":"Monthly_TapIn","TOTAL_TAP_OUT_VOLUME":"Monthly_TapOut"}, inplace=True)
df.index.rename(['BusStopCode','DayType','TimePerHour'], inplace=True)
display(df)
# Out:
#                                           Monthly_TapIn  Monthly_TapOut
# BusStopCode DayType          TimePerHour
# 1012        WEEKDAY          0                      272              74
#                              1                        3               1
#                              5                       20              44
#                              6                      190             303
#                              7                      354             445
# ...                                                 ...             ...
# 99189       WEEKENDS/HOLIDAY 19                      65              97
#                              20                      48              91
#                              21                      38              56
#                              22                      15              68
#                              23                      12              27
#
# [196614 rows x 2 columns]

# %%
print(df.dtypes)
print(df.isnull().sum())
# Out:
# Monthly_TapIn     int32
# Monthly_TapOut    int32
# dtype: object
# Monthly_TapIn     0
# Monthly_TapOut    0
# dtype: int64

# %%
display(df.head(),df.tail())
# Out:
#                                  Monthly_TapIn  Monthly_TapOut
# BusStopCode DayType TimePerHour
# 1012        WEEKDAY 0                      272              74
#                     1                        3               1
#                     5                       20              44
#                     6                      190             303
#                     7                      354             445
#                                           Monthly_TapIn  Monthly_TapOut
# BusStopCode DayType          TimePerHour
# 99189       WEEKENDS/HOLIDAY 19                      65              97
#                              20                      48              91
#                              21                      38              56
#                              22                      15              68
#                              23                      12              27

# %%
# Right back to csv (higher level of granularity)
df.to_csv('./data/bus_demand_high_LOD.csv')

# %%
# Downsample TimePerHour into four categories (6-8:59,9-16:59,17-18:59,19-5:59) so that it can merge with the categorized
# level of data in the bus
df.reset_index(inplace=True)
# Prepare data for pd.cut
beforeValueCount = df["TimePerHour"].value_counts().sort_index()
df["TimePerHour"] = df["TimePerHour"].apply(lambda x: x-6 if x>5 else x+18)
afterValueCount = df["TimePerHour"].value_counts().sort_index()

# Show the two series side by side
print(pd.concat([beforeValueCount,afterValueCount], axis=1, keys=["Before","After"]))
# Out:
#     Before  After
# 0     8318   9833
# 1     3936   9758
# 2      825   9690
# 3      327   9830
# 4      143   9854
# 5     7094   9874
# 6     9833   9881
# 7     9758   9891
# 8     9690   9908
# 9     9830   9884
# 10    9854   9840
# 11    9874   9710
# 12    9881   9589
# 13    9891   9706
# 14    9908   9823
# 15    9884   9669
# 16    9840   9647
# 17    9710   9584
# 18    9589   8318
# 19    9706   3936
# 20    9823    825
# 21    9669    327
# 22    9647    143
# 23    9584   7094

# %%
# Now we can use cut
# Bins 0,2 (6-8:59) ,10 (9-16:59), 12 (17-18:59), inf (After 19:00)
df["TimeCat"] = pd.cut(df["TimePerHour"], bins=[0,2,10,12,len(df["TimePerHour"])] , labels=["AM_Peak","AM_Offpeak","PM_Peak","PM_Offpeak"], right=True,include_lowest=True)
# Convert TimePerHour back
df["TimePerHour"] = df["TimePerHour"].apply(lambda x: x+6 if x<18 else x-18)
# Check in all unique rows whether Category is corretly assigned
display(df[["TimePerHour","TimeCat"]].drop_duplicates(keep='first').sort_values("TimePerHour"))
# Out:
#       TimePerHour     TimeCat
# 0               0  PM_Offpeak
# 1               1  PM_Offpeak
# 245             2  PM_Offpeak
# 3942            3  PM_Offpeak
# 4676            4  PM_Offpeak
# 2               5  PM_Offpeak
# 3               6     AM_Peak
# 4               7     AM_Peak
# 5               8     AM_Peak
# 6               9  AM_Offpeak
# 7              10  AM_Offpeak
# 8              11  AM_Offpeak
# 9              12  AM_Offpeak
# 10             13  AM_Offpeak
# 11             14  AM_Offpeak
# 12             15  AM_Offpeak
# 13             16  AM_Offpeak
# 14             17     PM_Peak
# 15             18     PM_Peak
# 16             19  PM_Offpeak
# 17             20  PM_Offpeak
# 18             21  PM_Offpeak
# 19             22  PM_Offpeak
# 20             23  PM_Offpeak

# %%
print(df.isnull().sum())
# Out:
# BusStopCode       0
# DayType           0
# TimePerHour       0
# Monthly_TapIn     0
# Monthly_TapOut    0
# TimeCat           0
# dtype: int64

# %%
display(df[df["BusStopCode"]==1012])
# Out:
#     BusStopCode           DayType  TimePerHour  Monthly_TapIn  Monthly_TapOut  \
# 0          1012           WEEKDAY            0            272              74
# 1          1012           WEEKDAY            1              3               1
# 2          1012           WEEKDAY            5             20              44
# 3          1012           WEEKDAY            6            190             303
# 4          1012           WEEKDAY            7            354             445
# 5          1012           WEEKDAY            8            425            1029
# 6          1012           WEEKDAY            9            356            1138
# 7          1012           WEEKDAY           10            410            1101
# 8          1012           WEEKDAY           11            604            1247
# 9          1012           WEEKDAY           12            674            1323
# 10         1012           WEEKDAY           13            748            1209
# 11         1012           WEEKDAY           14            892            1175
# 12         1012           WEEKDAY           15           1020            1122
# 13         1012           WEEKDAY           16           1355            1201
# 14         1012           WEEKDAY           17           1442            1267
# 15         1012           WEEKDAY           18           1443            1385
# 16         1012           WEEKDAY           19           1201             908
# 17         1012           WEEKDAY           20            806             537
# 18         1012           WEEKDAY           21           1043             450
# 19         1012           WEEKDAY           22           1000             373
# 20         1012           WEEKDAY           23            527             219
# 21         1012  WEEKENDS/HOLIDAY            0            164              46
# 22         1012  WEEKENDS/HOLIDAY            1              0               1
# 23         1012  WEEKENDS/HOLIDAY            5             18              16
# 24         1012  WEEKENDS/HOLIDAY            6             79             110
# 25         1012  WEEKENDS/HOLIDAY            7            125             179
# 26         1012  WEEKENDS/HOLIDAY            8            135             315
# 27         1012  WEEKENDS/HOLIDAY            9            180             494
# 28         1012  WEEKENDS/HOLIDAY           10            235             556
# 29         1012  WEEKENDS/HOLIDAY           11            314             596
# 30         1012  WEEKENDS/HOLIDAY           12            364             680
# 31         1012  WEEKENDS/HOLIDAY           13            402             778
# 32         1012  WEEKENDS/HOLIDAY           14            455             642
# 33         1012  WEEKENDS/HOLIDAY           15            510             622
# 34         1012  WEEKENDS/HOLIDAY           16            541             711
# 35         1012  WEEKENDS/HOLIDAY           17            558             625
# 36         1012  WEEKENDS/HOLIDAY           18            572             479
# 37         1012  WEEKENDS/HOLIDAY           19            488             395
# 38         1012  WEEKENDS/HOLIDAY           20            359             250
# 39         1012  WEEKENDS/HOLIDAY           21            437             221
# 40         1012  WEEKENDS/HOLIDAY           22            416             201
# 41         1012  WEEKENDS/HOLIDAY           23            269             116
#
#        TimeCat
# 0   PM_Offpeak
# 1   PM_Offpeak
# 2   PM_Offpeak
# 3      AM_Peak
# 4      AM_Peak
# 5      AM_Peak
# 6   AM_Offpeak
# 7   AM_Offpeak
# 8   AM_Offpeak
# 9   AM_Offpeak
# 10  AM_Offpeak
# 11  AM_Offpeak
# 12  AM_Offpeak
# 13  AM_Offpeak
# 14     PM_Peak
# 15     PM_Peak
# 16  PM_Offpeak
# 17  PM_Offpeak
# 18  PM_Offpeak
# 19  PM_Offpeak
# 20  PM_Offpeak
# 21  PM_Offpeak
# 22  PM_Offpeak
# 23  PM_Offpeak
# 24     AM_Peak
# 25     AM_Peak
# 26     AM_Peak
# 27  AM_Offpeak
# 28  AM_Offpeak
# 29  AM_Offpeak
# 30  AM_Offpeak
# 31  AM_Offpeak
# 32  AM_Offpeak
# 33  AM_Offpeak
# 34  AM_Offpeak
# 35     PM_Peak
# 36     PM_Peak
# 37  PM_Offpeak
# 38  PM_Offpeak
# 39  PM_Offpeak
# 40  PM_Offpeak
# 41  PM_Offpeak

# %%
df.drop(columns=["TimePerHour"], inplace=True)
df.set_index(["BusStopCode","DayType","TimeCat"], inplace=True)
df = df.groupby(["BusStopCode","DayType","TimeCat"]).agg({"Monthly_TapIn":"mean","Monthly_TapOut":"mean"})
# Shows missing values since some Bus Stops don't have categories because they have no Tap In and Tap Out
# at that time category. Hence, we should impute them with zeros (since their mean Tap In and Tap out
# would also be zero)
print(df.isnull().sum())
display(df[df.isnull().any(axis=1)])
# Out:
# Monthly_TapIn     953
# Monthly_TapOut    953
# dtype: int64
#                                          Monthly_TapIn  Monthly_TapOut
# BusStopCode DayType          TimeCat
# 1112        WEEKDAY          PM_Peak               NaN             NaN
# 1311        WEEKDAY          PM_Peak               NaN             NaN
# 1319        WEEKDAY          PM_Peak               NaN             NaN
# 3241        WEEKDAY          PM_Offpeak            NaN             NaN
#             WEEKENDS/HOLIDAY AM_Peak               NaN             NaN
# ...                                                ...             ...
# 98209       WEEKENDS/HOLIDAY PM_Offpeak            NaN             NaN
# 98219       WEEKENDS/HOLIDAY PM_Peak               NaN             NaN
#                              PM_Offpeak            NaN             NaN
# 98229       WEEKENDS/HOLIDAY PM_Peak               NaN             NaN
#                              PM_Offpeak            NaN             NaN
#
# [953 rows x 2 columns]

# %%
df.fillna(0, inplace=True)
df.round()
df[['Monthly_TapIn','Monthly_TapOut']] = df[['Monthly_TapIn','Monthly_TapOut']].astype("int")
print(df.isnull().sum())
display(df)
# Out:
# Monthly_TapIn     0
# Monthly_TapOut    0
# dtype: int64
#                                          Monthly_TapIn  Monthly_TapOut
# BusStopCode DayType          TimeCat
# 1012        WEEKDAY          AM_Peak               323             592
#                              AM_Offpeak            757            1189
#                              PM_Peak              1442            1326
#                              PM_Offpeak            609             325
#             WEEKENDS/HOLIDAY AM_Peak               113             201
# ...                                                ...             ...
# 99189       WEEKDAY          PM_Offpeak             33             207
#             WEEKENDS/HOLIDAY AM_Peak                10              45
#                              AM_Offpeak             37              93
#                              PM_Peak                60             125
#                              PM_Offpeak             30              58
#
# [40688 rows x 2 columns]

# %%
df.reset_index(inplace=True)

# %%
# Long to wide for TimeCat (pivot)
df = df.pivot(index=["BusStopCode","DayType"], columns="TimeCat", values=["Monthly_TapIn","Monthly_TapOut"])
df.columns = ["Monthly_TapIn_AM_Peak","Monthly_TapIn_AM_Offpeak","Monthly_TapIn_PM_Peak","Monthly_TapIn_PM_Offpeak","Monthly_TapOut_AM_Peak","Monthly_TapOut_AM_Offpeak","Monthly_TapOut_PM_Peak","Monthly_TapOut_PM_Offpeak"]
df.reset_index(inplace=True)

# Long to wide for DayType
df = df.pivot(index="BusStopCode", columns="DayType", values=["Monthly_TapIn_AM_Peak","Monthly_TapIn_AM_Offpeak","Monthly_TapIn_PM_Peak","Monthly_TapIn_PM_Offpeak","Monthly_TapOut_AM_Peak","Monthly_TapOut_AM_Offpeak","Monthly_TapOut_PM_Peak","Monthly_TapOut_PM_Offpeak"])
df.columns = ["Weekday_Monthly_TapIn_AM_Peak","Weekend/Hols_Monthly_TapIn_AM_Peak","Weekday_Monthly_TapIn_AM_Offpeak","Weekend/Hols_Monthly_TapIn_AM_Offpeak","Weekday_Monthly_TapIn_PM_Peak","Weekend/Hols_Monthly_TapIn_PM_Peak","Weekday_Monthly_TapIn_PM_Offpeak","Weekend/Hols_Monthly_TapIn_PM_Offpeak","Weekday_Monthly_TapOut_AM_Peak","Weekend/Hols_Monthly_TapOut_AM_Peak","Weekday_Monthly_TapOut_AM_Offpeak","Weekend/Hols_Monthly_TapOut_AM_Offpeak","Weekday_Monthly_TapOut_PM_Peak","Weekend/Hols_Monthly_TapOut_PM_Peak","Weekday_Monthly_TapOut_PM_Offpeak","Weekend/Hols_Monthly_TapOut_PM_Offpeak"]
display(df)
# Out:
#              Weekday_Monthly_TapIn_AM_Peak  \
# BusStopCode
# 1012                                   323
# 1013                                   181
# 1019                                   235
# 1029                                   327
# 1039                                   327
# ...                                    ...
# 99139                                    0
# 99161                                    1
# 99171                                    4
# 99181                                  740
# 99189                                   22
#
#              Weekend/Hols_Monthly_TapIn_AM_Peak  \
# BusStopCode
# 1012                                        113
# 1013                                         61
# 1019                                         70
# 1029                                         99
# 1039                                        110
# ...                                         ...
# 99139                                         0
# 99161                                         0
# 99171                                         2
# 99181                                       218
# 99189                                        10
#
#              Weekday_Monthly_TapIn_AM_Offpeak  \
# BusStopCode
# 1012                                      757
# 1013                                      515
# 1019                                      571
# 1029                                      921
# 1039                                     1354
# ...                                       ...
# 99139                                       2
# 99161                                       1
# 99171                                      11
# 99181                                     293
# 99189                                      87
#
#              Weekend/Hols_Monthly_TapIn_AM_Offpeak  \
# BusStopCode
# 1012                                           375
# 1013                                           291
# 1019                                           274
# 1029                                           487
# 1039                                           866
# ...                                            ...
# 99139                                            0
# 99161                                            1
# 99171                                            9
# 99181                                          108
# 99189                                           37
#
#              Weekday_Monthly_TapIn_PM_Peak  \
# BusStopCode
# 1012                                  1442
# 1013                                  1210
# 1019                                   678
# 1029                                  1498
# 1039                                  1905
# ...                                    ...
# 99139                                    0
# 99161                                    3
# 99171                                   16
# 99181                                  159
# 99189                                  139
#
#              Weekend/Hols_Monthly_TapIn_PM_Peak  \
# BusStopCode
# 1012                                        565
# 1013                                        502
# 1019                                        313
# 1029                                        647
# 1039                                       1221
# ...                                         ...
# 99139                                         1
# 99161                                         3
# 99171                                        16
# 99181                                        97
# 99189                                        60
#
#              Weekday_Monthly_TapIn_PM_Offpeak  \
# BusStopCode
# 1012                                      609
# 1013                                      658
# 1019                                      198
# 1029                                      463
# 1039                                     1048
# ...                                       ...
# 99139                                       0
# 99161                                       1
# 99171                                       6
# 99181                                     156
# 99189                                      33
#
#              Weekend/Hols_Monthly_TapIn_PM_Offpeak  \
# BusStopCode
# 1012                                           268
# 1013                                           274
# 1019                                            69
# 1029                                           198
# 1039                                           529
# ...                                            ...
# 99139                                            0
# 99161                                            2
# 99171                                            5
# 99181                                           86
# 99189                                           30
#
#              Weekday_Monthly_TapOut_AM_Peak  \
# BusStopCode
# 1012                                    592
# 1013                                    214
# 1019                                    742
# 1029                                    703
# 1039                                    864
# ...                                     ...
# 99139                                   535
# 99161                                    24
# 99171                                    40
# 99181                                   541
# 99189                                    94
#
#              Weekend/Hols_Monthly_TapOut_AM_Peak  \
# BusStopCode
# 1012                                         201
# 1013                                          71
# 1019                                         241
# 1029                                         196
# 1039                                         291
# ...                                          ...
# 99139                                        241
# 99161                                          6
# 99171                                         35
# 99181                                        203
# 99189                                         45
#
#              Weekday_Monthly_TapOut_AM_Offpeak  \
# BusStopCode
# 1012                                      1189
# 1013                                       454
# 1019                                       976
# 1029                                       785
# 1039                                      1714
# ...                                        ...
# 99139                                      569
# 99161                                       17
# 99171                                       83
# 99181                                      278
# 99189                                      211
#
#              Weekend/Hols_Monthly_TapOut_AM_Offpeak  \
# BusStopCode
# 1012                                            634
# 1013                                            243
# 1019                                            497
# 1029                                            409
# 1039                                           1017
# ...                                             ...
# 99139                                           451
# 99161                                            15
# 99171                                            90
# 99181                                           182
# 99189                                            93
#
#              Weekday_Monthly_TapOut_PM_Peak  \
# BusStopCode
# 1012                                   1326
# 1013                                    592
# 1019                                    728
# 1029                                    635
# 1039                                   1642
# ...                                     ...
# 99139                                   642
# 99161                                    29
# 99171                                    78
# 99181                                   354
# 99189                                   414
#
#              Weekend/Hols_Monthly_TapOut_PM_Peak  \
# BusStopCode
# 1012                                         552
# 1013                                         215
# 1019                                         337
# 1029                                         270
# 1039                                         911
# ...                                          ...
# 99139                                        540
# 99161                                         30
# 99171                                        151
# 99181                                        277
# 99189                                        125
#
#              Weekday_Monthly_TapOut_PM_Offpeak  \
# BusStopCode
# 1012                                       325
# 1013                                       207
# 1019                                       198
# 1029                                       140
# 1039                                       446
# ...                                        ...
# 99139                                      305
# 99161                                        5
# 99171                                       18
# 99181                                      113
# 99189                                      207
#
#              Weekend/Hols_Monthly_TapOut_PM_Offpeak
# BusStopCode
# 1012                                            155
# 1013                                            102
# 1019                                             74
# 1029                                             59
# 1039                                            205
# ...                                             ...
# 99139                                           187
# 99161                                             7
# 99171                                            18
# 99181                                            84
# 99189                                            58
#
# [5086 rows x 16 columns]

# %%
df.to_csv('./data/bus_demand_low_LOD.csv')

# %% [markdown]
# ## Dashboard 1
# ### Dataset 2 (Bus Capacity)
# url: https://datamall.lta.gov.sg/content/datamall/en/dynamic-data.html
#
# Used: Bus Services, Bus Stops, Bus Routes

# %%
# Convert json from a file into dictionary
stops = pd.read_csv('./datasrc/bus_stops.csv', na_values=['-','NaN'])
routes = pd.read_csv('./datasrc/bus_routes.csv', na_values=['-','NaN'])
services = pd.read_csv('./datasrc/bus_services.csv', na_values=['-','NaN'])
routes = routes.drop(columns = ['Unnamed: 0'])
services = services.drop(columns = ['Unnamed: 0'])
stops = stops.drop(columns = ['Unnamed: 0'])

# %%
# Apparently there is just one value in routes that is not numeric (E0323)
tmp = [x for x in routes["BusStopCode"] if not x.isnumeric()]
print(tmp)
# Out:
# ['E0323']

# %%
# There is only one row with the BusStopCode E0323 and it is on row 18622
print(routes[routes['BusStopCode']=="E0323"])
# Out:
#       ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 18622       700     SMRT          2             2       E0323       0.0
#
#        WD_FirstBus  WD_LastBus  SAT_FirstBus  SAT_LastBus SUN_FirstBus  \
# 18622        630.0      1930.0         630.0       1400.0          NaN
#
#        SUN_LastBus
# 18622          NaN

# %%
# Since the value with the faulty BusStopCode (E0323) has essentially the same data as the row before it, we can
# safely drop the row
display(routes.iloc[18621:18624])
routes.drop(18622, inplace=True)
# Out:
#       ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 18621       700     SMRT          2             1       03239       0.0
# 18622       700     SMRT          2             2       E0323       0.0
# 18623       700     SMRT          2             3       03223       0.7
#
#        WD_FirstBus  WD_LastBus  SAT_FirstBus  SAT_LastBus SUN_FirstBus  \
# 18621        630.0      1930.0         630.0       1400.0          NaN
# 18622        630.0      1930.0         630.0       1400.0          NaN
# 18623        632.0      1933.0         632.0       1403.0          NaN
#
#        SUN_LastBus
# 18621          NaN
# 18622          NaN
# 18623          NaN

# %%
# Now I can safely convert the row into an int
routes["BusStopCode"] = routes["BusStopCode"].astype(int)

# %%
df1 = pd.merge(routes, stops, on="BusStopCode", how="inner")
df1.sort_values(['ServiceNo', 'Direction','StopSequence'], inplace=True)
df = pd.merge(df1, services, on=["ServiceNo","Operator","Direction"], how="inner")
print(len(df))
# Out:
# 26485

# %%
def avg_list(series_element):
    if type(series_element) == list:
        # If it has two values (eg. 9-12 converted into [9,12])
        if len(series_element)==2:
            return (float(series_element[0])+float(series_element[1]))//2
        else:
            # If it has one value (e.g. 29 converted into [29])
            return float(series_element[0])
    else:
        # If it is NaN (since the bus did not provide any information, it does not operate at that time and thus has
        # no passengers at that frequency)
        return 0

# %%
AM_PEAK = df['AM_Peak_Freq'].str.split('-')
AM_PEAK = AM_PEAK.apply(avg_list)
AM_OFFPEAK = df['AM_Offpeak_Freq'].str.split('-')
AM_OFFPEAK = AM_OFFPEAK.apply(avg_list)
PM_PEAK = df['PM_Peak_Freq'].str.split('-')
PM_PEAK = PM_PEAK.apply(avg_list)
PM_OFFPEAK = df['PM_Offpeak_Freq'].str.split('-')
PM_OFFPEAK = PM_OFFPEAK.apply(avg_list)

df['AM_Peak_avg'] = AM_PEAK
df['AM_Offpeak_avg'] = AM_OFFPEAK
df['PM_Peak_avg'] = PM_PEAK
df['PM_Offpeak_avg'] = PM_OFFPEAK

# %%
df.set_index(['ServiceNo','Direction','StopSequence'], inplace=True)
df.sort_index()
display(df)
# Out:
#                                  Operator  BusStopCode  Distance  WD_FirstBus  \
# ServiceNo Direction StopSequence
# 10        1         1                SBST        75009       0.0        500.0
#                     2                SBST        76059       0.6        502.0
#                     3                SBST        76069       1.1        504.0
#                     4                SBST        96289       2.3        508.0
#                     5                SBST        96109       2.7        509.0
# ...                                   ...          ...       ...          ...
# NR8       1         57               SMRT        43839      23.1          NaN
#                     58               SMRT        43649      23.4          NaN
#                     59               SMRT        43589      23.9          NaN
#                     60               SMRT        43579      24.3          NaN
#                     61               SMRT        43609      24.6          NaN
#
#                                   WD_LastBus  SAT_FirstBus  SAT_LastBus  \
# ServiceNo Direction StopSequence
# 10        1         1                 2300.0         500.0       2300.0
#                     2                 2302.0         502.0       2302.0
#                     3                 2304.0         504.0       2304.0
#                     4                 2308.0         508.0       2309.0
#                     5                 2310.0         509.0       2311.0
# ...                                      ...           ...          ...
# NR8       1         57                   NaN          28.0        254.0
#                     58                   NaN          29.0        255.0
#                     59                   NaN          30.0        256.0
#                     60                   NaN          31.0        257.0
#                     61                   NaN          32.0        258.0
#
#                                  SUN_FirstBus  SUN_LastBus  \
# ServiceNo Direction StopSequence
# 10        1         1                    0500       2300.0
#                     2                    0502       2302.0
#                     3                    0503       2304.0
#                     4                    0507       2308.0
#                     5                    0508       2309.0
# ...                                       ...          ...
# NR8       1         57                    NaN          NaN
#                     58                    NaN          NaN
#                     59                    NaN          NaN
#                     60                    NaN          NaN
#                     61                    NaN          NaN
#
#                                              RoadName  ... DestinationCode  \
# ServiceNo Direction StopSequence                       ...
# 10        1         1                 Tampines Ctrl 1  ...         16009.0
#                     2                  Tampines Ave 5  ...         16009.0
#                     3                  Tampines Ave 5  ...         16009.0
#                     4                       Simei Ave  ...         16009.0
#                     5                       Simei Ave  ...         16009.0
# ...                                               ...  ...             ...
# NR8       1         57            Bt Batok West Ave 7  ...         43609.0
#                     58            Bt Batok West Ave 7  ...         43609.0
#                     59            Bt Batok West Ave 5  ...         43609.0
#                     60            Bt Batok West Ave 5  ...         43609.0
#                     61            Bt Batok West Ave 5  ...         43609.0
#
#                                   AM_Peak_Freq  AM_Offpeak_Freq PM_Peak_Freq  \
# ServiceNo Direction StopSequence
# 10        1         1                    08-09            06-17        10-15
#                     2                    08-09            06-17        10-15
#                     3                    08-09            06-17        10-15
#                     4                    08-09            06-17        10-15
#                     5                    08-09            06-17        10-15
# ...                                        ...              ...          ...
# NR8       1         57                     NaN              NaN          NaN
#                     58                     NaN              NaN          NaN
#                     59                     NaN              NaN          NaN
#                     60                     NaN              NaN          NaN
#                     61                     NaN              NaN          NaN
#
#                                   PM_Offpeak_Freq             LoopDesc  \
# ServiceNo Direction StopSequence
# 10        1         1                       11-18                  NaN
#                     2                       11-18                  NaN
#                     3                       11-18                  NaN
#                     4                       11-18                  NaN
#                     5                       11-18                  NaN
# ...                                           ...                  ...
# NR8       1         57                      29-29  Bt Batok West Ave 5
#                     58                      29-29  Bt Batok West Ave 5
#                     59                      29-29  Bt Batok West Ave 5
#                     60                      29-29  Bt Batok West Ave 5
#                     61                      29-29  Bt Batok West Ave 5
#
#                                  AM_Peak_avg AM_Offpeak_avg PM_Peak_avg  \
# ServiceNo Direction StopSequence
# 10        1         1                    8.0           11.0        12.0
#                     2                    8.0           11.0        12.0
#                     3                    8.0           11.0        12.0
#                     4                    8.0           11.0        12.0
#                     5                    8.0           11.0        12.0
# ...                                      ...            ...         ...
# NR8       1         57                   0.0            0.0         0.0
#                     58                   0.0            0.0         0.0
#                     59                   0.0            0.0         0.0
#                     60                   0.0            0.0         0.0
#                     61                   0.0            0.0         0.0
#
#                                  PM_Offpeak_avg
# ServiceNo Direction StopSequence
# 10        1         1                      14.0
#                     2                      14.0
#                     3                      14.0
#                     4                      14.0
#                     5                      14.0
# ...                                         ...
# NR8       1         57                     29.0
#                     58                     29.0
#                     59                     29.0
#                     60                     29.0
#                     61                     29.0
#
# [26485 rows x 25 columns]

# %%
# Check missing values in distance
df[df["Distance"].isnull()]
# Out:
#                                  Operator  BusStopCode  Distance  WD_FirstBus  \
# ServiceNo Direction StopSequence
# 185       1         1                SBST        22609       NaN        545.0
#           2         1                SBST        11379       NaN        600.0
# 200       1         1                SBST        11379       NaN        600.0
# 252       1         37               SBST        22009       NaN        630.0
# 2N        1         1                SBST         2099       NaN          NaN
#
#                                   WD_LastBus  SAT_FirstBus  SAT_LastBus  \
# ServiceNo Direction StopSequence
# 185       1         1                 2315.0         545.0       2315.0
#           2         1                 2300.0         600.0       2300.0
# 200       1         1                 2329.0         600.0       2335.0
# 252       1         37                   2.0         631.0       2400.0
# 2N        1         1                    NaN        2400.0        200.0
#
#                                  SUN_FirstBus  SUN_LastBus  \
# ServiceNo Direction StopSequence
# 185       1         1                    0545       2315.0
#           2         1                    0600       2300.0
# 200       1         1                    0600       2336.0
# 252       1         37                   0630          1.0
# 2N        1         1                     NaN          NaN
#
#                                             RoadName  ... DestinationCode  \
# ServiceNo Direction StopSequence                      ...
# 185       1         1                    Soon Lee Rd  ...         11389.0
#           2         1             Nth Buona Vista Rd  ...         22199.0
# 200       1         1             Nth Buona Vista Rd  ...         11389.0
# 252       1         37            Jurong West Ctrl 3  ...         22009.0
# 2N        1         1                   Raffles Blvd  ...         75109.0
#
#                                   AM_Peak_Freq  AM_Offpeak_Freq PM_Peak_Freq  \
# ServiceNo Direction StopSequence
# 185       1         1                    10-18            11-18        12-15
#           2         1                    10-17            10-15        10-20
# 200       1         1                     9-10             9-30         9-10
# 252       1         37                    8-10             7-18          7-9
# 2N        1         1                      NaN              NaN          NaN
#
#                                   PM_Offpeak_Freq     LoopDesc AM_Peak_avg  \
# ServiceNo Direction StopSequence
# 185       1         1                       13-15          NaN        14.0
#           2         1                       14-16          NaN        13.0
# 200       1         1                       14-27  Clementi Rd         9.0
# 252       1         37                       8-20  Joo Koon Rd         9.0
# 2N        1         1                       40-40          NaN         0.0
#
#                                  AM_Offpeak_avg PM_Peak_avg PM_Offpeak_avg
# ServiceNo Direction StopSequence
# 185       1         1                      14.0        13.0           14.0
#           2         1                      12.0        15.0           15.0
# 200       1         1                      19.0         9.0           20.0
# 252       1         37                     12.0         8.0           14.0
# 2N        1         1                       0.0         0.0           40.0
#
# [5 rows x 25 columns]

# %%
# Determining missing values using Deterministic Regression Imputation
model = linear_model.LinearRegression()
# Removes the last value which is nan in y_values
x_values = np.array(df.loc["252",1].index.to_list())[0:-1]
# Reshape according to docs
x_values = x_values.reshape(-1,1)
# Removes the last value which is nan
y_values = np.array(df.loc[("252",1),"Distance"].to_list())[0:-1]
model.fit(X = x_values, y = y_values)

prediction = model.predict([[np.array(df.loc["252",1].index.to_list())[-1]]])

# %%
df.loc[("252",1,37),"Distance"] = round(prediction[0],1)
display(df.loc[("252",1,37)])
# Out:
#                                  Operator  BusStopCode  Distance  WD_FirstBus  \
# ServiceNo Direction StopSequence
# 252       1         37               SBST        22009      14.2        630.0
#
#                                   WD_LastBus  SAT_FirstBus  SAT_LastBus  \
# ServiceNo Direction StopSequence
# 252       1         37                   2.0         631.0       2400.0
#
#                                  SUN_FirstBus  SUN_LastBus  \
# ServiceNo Direction StopSequence
# 252       1         37                   0630          1.0
#
#                                             RoadName  ... DestinationCode  \
# ServiceNo Direction StopSequence                      ...
# 252       1         37            Jurong West Ctrl 3  ...         22009.0
#
#                                   AM_Peak_Freq  AM_Offpeak_Freq PM_Peak_Freq  \
# ServiceNo Direction StopSequence
# 252       1         37                    8-10             7-18          7-9
#
#                                   PM_Offpeak_Freq     LoopDesc AM_Peak_avg  \
# ServiceNo Direction StopSequence
# 252       1         37                       8-20  Joo Koon Rd         9.0
#
#                                  AM_Offpeak_avg PM_Peak_avg PM_Offpeak_avg
# ServiceNo Direction StopSequence
# 252       1         37                     12.0         8.0           14.0
#
# [1 rows x 25 columns]

# %%
# Since they are all the first stop, we can just fill with 0
df["Distance"].fillna(0, inplace=True)

# %%
# Drop the freq since we extracted it to avg and drop the loop
df.drop(columns=["AM_Peak_Freq","AM_Offpeak_Freq","PM_Peak_Freq","PM_Offpeak_Freq"], inplace=True)

# %%
df["LoopDesc"] = df["LoopDesc"].apply(lambda x: 'N' if type(x)==float else 'Y')
display(df)
# Out:
#                                  Operator  BusStopCode  Distance  WD_FirstBus  \
# ServiceNo Direction StopSequence
# 10        1         1                SBST        75009       0.0        500.0
#                     2                SBST        76059       0.6        502.0
#                     3                SBST        76069       1.1        504.0
#                     4                SBST        96289       2.3        508.0
#                     5                SBST        96109       2.7        509.0
# ...                                   ...          ...       ...          ...
# NR8       1         57               SMRT        43839      23.1          NaN
#                     58               SMRT        43649      23.4          NaN
#                     59               SMRT        43589      23.9          NaN
#                     60               SMRT        43579      24.3          NaN
#                     61               SMRT        43609      24.6          NaN
#
#                                   WD_LastBus  SAT_FirstBus  SAT_LastBus  \
# ServiceNo Direction StopSequence
# 10        1         1                 2300.0         500.0       2300.0
#                     2                 2302.0         502.0       2302.0
#                     3                 2304.0         504.0       2304.0
#                     4                 2308.0         508.0       2309.0
#                     5                 2310.0         509.0       2311.0
# ...                                      ...           ...          ...
# NR8       1         57                   NaN          28.0        254.0
#                     58                   NaN          29.0        255.0
#                     59                   NaN          30.0        256.0
#                     60                   NaN          31.0        257.0
#                     61                   NaN          32.0        258.0
#
#                                  SUN_FirstBus  SUN_LastBus  \
# ServiceNo Direction StopSequence
# 10        1         1                    0500       2300.0
#                     2                    0502       2302.0
#                     3                    0503       2304.0
#                     4                    0507       2308.0
#                     5                    0508       2309.0
# ...                                       ...          ...
# NR8       1         57                    NaN          NaN
#                     58                    NaN          NaN
#                     59                    NaN          NaN
#                     60                    NaN          NaN
#                     61                    NaN          NaN
#
#                                              RoadName  ...  Latitude  \
# ServiceNo Direction StopSequence                       ...
# 10        1         1                 Tampines Ctrl 1  ...  1.354076
#                     2                  Tampines Ave 5  ...  1.352962
#                     3                  Tampines Ave 5  ...  1.348753
#                     4                       Simei Ave  ...  1.340055
#                     5                       Simei Ave  ...  1.337371
# ...                                               ...  ...       ...
# NR8       1         57            Bt Batok West Ave 7  ...  1.365273
#                     58            Bt Batok West Ave 7  ...  1.365458
#                     59            Bt Batok West Ave 5  ...  1.362273
#                     60            Bt Batok West Ave 5  ...  1.359117
#                     61            Bt Batok West Ave 5  ...  1.356536
#
#                                    Longitude     Category OriginCode  \
# ServiceNo Direction StopSequence
# 10        1         1             103.943391        TRUNK    75009.0
#                     2             103.941652        TRUNK    75009.0
#                     3             103.942086        TRUNK    75009.0
#                     4             103.948381        TRUNK    75009.0
#                     5             103.950673        TRUNK    75009.0
# ...                                      ...          ...        ...
# NR8       1         57            103.748250  NIGHT RIDER     2099.0
#                     58            103.750602  NIGHT RIDER     2099.0
#                     59            103.751532  NIGHT RIDER     2099.0
#                     60            103.751668  NIGHT RIDER     2099.0
#                     61            103.749924  NIGHT RIDER     2099.0
#
#                                   DestinationCode  LoopDesc AM_Peak_avg  \
# ServiceNo Direction StopSequence
# 10        1         1                     16009.0         N         8.0
#                     2                     16009.0         N         8.0
#                     3                     16009.0         N         8.0
#                     4                     16009.0         N         8.0
#                     5                     16009.0         N         8.0
# ...                                           ...       ...         ...
# NR8       1         57                    43609.0         Y         0.0
#                     58                    43609.0         Y         0.0
#                     59                    43609.0         Y         0.0
#                     60                    43609.0         Y         0.0
#                     61                    43609.0         Y         0.0
#
#                                   AM_Offpeak_avg  PM_Peak_avg  PM_Offpeak_avg
# ServiceNo Direction StopSequence
# 10        1         1                       11.0         12.0            14.0
#                     2                       11.0         12.0            14.0
#                     3                       11.0         12.0            14.0
#                     4                       11.0         12.0            14.0
#                     5                       11.0         12.0            14.0
# ...                                          ...          ...             ...
# NR8       1         57                       0.0          0.0            29.0
#                     58                       0.0          0.0            29.0
#                     59                       0.0          0.0            29.0
#                     60                       0.0          0.0            29.0
#                     61                       0.0          0.0            29.0
#
# [26485 rows x 21 columns]

# %%
df.dtypes
# Drop temporarily
df.drop(columns=["WD_FirstBus","WD_LastBus","SAT_FirstBus","SAT_LastBus","SUN_FirstBus","SUN_LastBus"], inplace=True)

# Convert Origin and Destination Code to int
df[['OriginCode','DestinationCode']]=df[['OriginCode','DestinationCode']].astype(int)

# Convert freq avg to int
df[['AM_Peak_avg','AM_Offpeak_avg','PM_Peak_avg','PM_Offpeak_avg']]=df[['AM_Peak_avg','AM_Offpeak_avg','PM_Peak_avg','PM_Offpeak_avg']].astype(int)
display(df)
# Out:
#                                  Operator  BusStopCode  Distance  \
# ServiceNo Direction StopSequence
# 10        1         1                SBST        75009       0.0
#                     2                SBST        76059       0.6
#                     3                SBST        76069       1.1
#                     4                SBST        96289       2.3
#                     5                SBST        96109       2.7
# ...                                   ...          ...       ...
# NR8       1         57               SMRT        43839      23.1
#                     58               SMRT        43649      23.4
#                     59               SMRT        43589      23.9
#                     60               SMRT        43579      24.3
#                     61               SMRT        43609      24.6
#
#                                              RoadName           Description  \
# ServiceNo Direction StopSequence
# 10        1         1                 Tampines Ctrl 1          Tampines Int
#                     2                  Tampines Ave 5  Opp Our Tampines Hub
#                     3                  Tampines Ave 5               Blk 147
#                     4                       Simei Ave   Changi General Hosp
#                     5                       Simei Ave          Opp Blk 3012
# ...                                               ...                   ...
# NR8       1         57            Bt Batok West Ave 7           Opp Blk 336
#                     58            Bt Batok West Ave 7            HomeTeamNS
#                     59            Bt Batok West Ave 5           Opp Blk 347
#                     60            Bt Batok West Ave 5         Bt Gombak Stn
#                     61            Bt Batok West Ave 5               Blk 531
#
#                                   Latitude   Longitude     Category  \
# ServiceNo Direction StopSequence
# 10        1         1             1.354076  103.943391        TRUNK
#                     2             1.352962  103.941652        TRUNK
#                     3             1.348753  103.942086        TRUNK
#                     4             1.340055  103.948381        TRUNK
#                     5             1.337371  103.950673        TRUNK
# ...                                    ...         ...          ...
# NR8       1         57            1.365273  103.748250  NIGHT RIDER
#                     58            1.365458  103.750602  NIGHT RIDER
#                     59            1.362273  103.751532  NIGHT RIDER
#                     60            1.359117  103.751668  NIGHT RIDER
#                     61            1.356536  103.749924  NIGHT RIDER
#
#                                   OriginCode  DestinationCode LoopDesc  \
# ServiceNo Direction StopSequence
# 10        1         1                  75009            16009        N
#                     2                  75009            16009        N
#                     3                  75009            16009        N
#                     4                  75009            16009        N
#                     5                  75009            16009        N
# ...                                      ...              ...      ...
# NR8       1         57                  2099            43609        Y
#                     58                  2099            43609        Y
#                     59                  2099            43609        Y
#                     60                  2099            43609        Y
#                     61                  2099            43609        Y
#
#                                   AM_Peak_avg  AM_Offpeak_avg  PM_Peak_avg  \
# ServiceNo Direction StopSequence
# 10        1         1                       8              11           12
#                     2                       8              11           12
#                     3                       8              11           12
#                     4                       8              11           12
#                     5                       8              11           12
# ...                                       ...             ...          ...
# NR8       1         57                      0               0            0
#                     58                      0               0            0
#                     59                      0               0            0
#                     60                      0               0            0
#                     61                      0               0            0
#
#                                   PM_Offpeak_avg
# ServiceNo Direction StopSequence
# 10        1         1                         14
#                     2                         14
#                     3                         14
#                     4                         14
#                     5                         14
# ...                                          ...
# NR8       1         57                        29
#                     58                        29
#                     59                        29
#                     60                        29
#                     61                        29
#
# [26485 rows x 15 columns]

# %%
print(df.isnull().sum())
print(df.dtypes)
# Out:
# Operator           0
# BusStopCode        0
# Distance           0
# RoadName           0
# Description        0
# Latitude           0
# Longitude          0
# Category           0
# OriginCode         0
# DestinationCode    0
# LoopDesc           0
# AM_Peak_avg        0
# AM_Offpeak_avg     0
# PM_Peak_avg        0
# PM_Offpeak_avg     0
# dtype: int64
# Operator            object
# BusStopCode          int32
# Distance           float64
# RoadName            object
# Description         object
# Latitude           float64
# Longitude          float64
# Category            object
# OriginCode           int32
# DestinationCode      int32
# LoopDesc            object
# AM_Peak_avg          int32
# AM_Offpeak_avg       int32
# PM_Peak_avg          int32
# PM_Offpeak_avg       int32
# dtype: object

# %%
# Write to csv
df.to_csv('data/bus_capacity.csv')

# %% [markdown]
# ### Merge low LOD bus demand with bus capacity

# %%
df1 = pd.read_csv('data/bus_capacity.csv')
df2 = pd.read_csv('data/bus_demand_low_LOD.csv')

# %%
df = pd.merge(df1, df2, on="BusStopCode", how="left")

# %%
null = df[df.isnull().any(axis=1)]
display(null.sort_values("ServiceNo"))
# Out:
#       ServiceNo  Direction  StopSequence Operator  BusStopCode  Distance  \
# 404         103          1            40     SBST        59671      17.5
# 1738        122          1            18     SBST        11479       7.2
# 2429        130          2            26     SBST        51041      10.4
# 2668        132          2            24     SBST        51041      10.5
# 3531        141          1            21     SBST        51041       6.8
# ...         ...        ...           ...      ...          ...       ...
# 26160       NR3          1            58     SMRT        45409      27.9
# 26161       NR3          1            59     SMRT        45381      28.1
# 26163       NR3          1            61     SMRT        45479      29.0
# 26236       NR5          1            76     SMRT        22571      29.6
# 26322       NR6          1            84     SMRT        67581      35.4
#
#                   RoadName       Description  Latitude   Longitude  ...  \
# 404           Yishun Ave 2    Bef Yishun Stn  1.427776  103.835187  ...
# 1738           Margaret Dr  The Fisherman Ch  1.299381  103.803720  ...
# 2429            Thomson Rd      Opp SLF Cplx  1.333436  103.837917  ...
# 2668            Thomson Rd      Opp SLF Cplx  1.333436  103.837917  ...
# 3531            Thomson Rd      Opp SLF Cplx  1.333436  103.837917  ...
# ...                    ...               ...       ...         ...  ...
# 26160   Choa Chu Kang Cres           Blk 675  1.401898  103.745796  ...
# 26161  Choa Chu Kang Nth 7  Blk 675A (LP 25)  1.400859  103.747128  ...
# 26163     Choa Chu Kang Dr     Kranji Pr Sch  1.394295  103.746520  ...
# 26236         Boon Lay Way  Opp Boon Lay Stn  1.337804  103.706891  ...
# 26322      Anchorvale Link          Blk 319A  1.391042  103.889747  ...
#
#       Weekday_Monthly_TapIn_PM_Offpeak  Weekend/Hols_Monthly_TapIn_PM_Offpeak  \
# 404                                NaN                                    NaN
# 1738                               NaN                                    NaN
# 2429                               NaN                                    NaN
# 2668                               NaN                                    NaN
# 3531                               NaN                                    NaN
# ...                                ...                                    ...
# 26160                              NaN                                    NaN
# 26161                              NaN                                    NaN
# 26163                              NaN                                    NaN
# 26236                              NaN                                    NaN
# 26322                              NaN                                    NaN
#
#        Weekday_Monthly_TapOut_AM_Peak Weekend/Hols_Monthly_TapOut_AM_Peak  \
# 404                               NaN                                 NaN
# 1738                              NaN                                 NaN
# 2429                              NaN                                 NaN
# 2668                              NaN                                 NaN
# 3531                              NaN                                 NaN
# ...                               ...                                 ...
# 26160                             NaN                                 NaN
# 26161                             NaN                                 NaN
# 26163                             NaN                                 NaN
# 26236                             NaN                                 NaN
# 26322                             NaN                                 NaN
#
#        Weekday_Monthly_TapOut_AM_Offpeak  \
# 404                                  NaN
# 1738                                 NaN
# 2429                                 NaN
# 2668                                 NaN
# 3531                                 NaN
# ...                                  ...
# 26160                                NaN
# 26161                                NaN
# 26163                                NaN
# 26236                                NaN
# 26322                                NaN
#
#        Weekend/Hols_Monthly_TapOut_AM_Offpeak  Weekday_Monthly_TapOut_PM_Peak  \
# 404                                       NaN                             NaN
# 1738                                      NaN                             NaN
# 2429                                      NaN                             NaN
# 2668                                      NaN                             NaN
# 3531                                      NaN                             NaN
# ...                                       ...                             ...
# 26160                                     NaN                             NaN
# 26161                                     NaN                             NaN
# 26163                                     NaN                             NaN
# 26236                                     NaN                             NaN
# 26322                                     NaN                             NaN
#
#        Weekend/Hols_Monthly_TapOut_PM_Peak  Weekday_Monthly_TapOut_PM_Offpeak  \
# 404                                    NaN                                NaN
# 1738                                   NaN                                NaN
# 2429                                   NaN                                NaN
# 2668                                   NaN                                NaN
# 3531                                   NaN                                NaN
# ...                                    ...                                ...
# 26160                                  NaN                                NaN
# 26161                                  NaN                                NaN
# 26163                                  NaN                                NaN
# 26236                                  NaN                                NaN
# 26322                                  NaN                                NaN
#
#        Weekend/Hols_Monthly_TapOut_PM_Offpeak
# 404                                       NaN
# 1738                                      NaN
# 2429                                      NaN
# 2668                                      NaN
# 3531                                      NaN
# ...                                       ...
# 26160                                     NaN
# 26161                                     NaN
# 26163                                     NaN
# 26236                                     NaN
# 26322                                     NaN
#
# [113 rows x 34 columns]

# %%
# Impute with the mean of tap in and tap out from the same service number and direction
null_subset = null[["ServiceNo","Direction"]].drop_duplicates()
print(len(null_subset))

tmp = df[["ServiceNo","Direction"]].stack().isin(null_subset.stack().values).unstack()

# print all values from df in tmp where at least 2 True
df[tmp.any(axis=1)]
# Out:
# 67
#       ServiceNo  Direction  StopSequence Operator  BusStopCode  Distance  \
# 0            10          1             1     SBST        75009       0.0
# 1            10          1             2     SBST        76059       0.6
# 2            10          1             3     SBST        76069       1.1
# 3            10          1             4     SBST        96289       2.3
# 4            10          1             5     SBST        96109       2.7
# ...         ...        ...           ...      ...          ...       ...
# 26480       NR8          1            57     SMRT        43839      23.1
# 26481       NR8          1            58     SMRT        43649      23.4
# 26482       NR8          1            59     SMRT        43589      23.9
# 26483       NR8          1            60     SMRT        43579      24.3
# 26484       NR8          1            61     SMRT        43609      24.6
#
#                   RoadName           Description  Latitude   Longitude  ...  \
# 0          Tampines Ctrl 1          Tampines Int  1.354076  103.943391  ...
# 1           Tampines Ave 5  Opp Our Tampines Hub  1.352962  103.941652  ...
# 2           Tampines Ave 5               Blk 147  1.348753  103.942086  ...
# 3                Simei Ave   Changi General Hosp  1.340055  103.948381  ...
# 4                Simei Ave          Opp Blk 3012  1.337371  103.950673  ...
# ...                    ...                   ...       ...         ...  ...
# 26480  Bt Batok West Ave 7           Opp Blk 336  1.365273  103.748250  ...
# 26481  Bt Batok West Ave 7            HomeTeamNS  1.365458  103.750602  ...
# 26482  Bt Batok West Ave 5           Opp Blk 347  1.362273  103.751532  ...
# 26483  Bt Batok West Ave 5         Bt Gombak Stn  1.359117  103.751668  ...
# 26484  Bt Batok West Ave 5               Blk 531  1.356536  103.749924  ...
#
#       Weekday_Monthly_TapIn_PM_Offpeak  Weekend/Hols_Monthly_TapIn_PM_Offpeak  \
# 0                               1088.0                                  633.0
# 1                               1645.0                                  526.0
# 2                               1014.0                                  318.0
# 3                                522.0                                  195.0
# 4                                131.0                                   60.0
# ...                                ...                                    ...
# 26480                             78.0                                   49.0
# 26481                            246.0                                  132.0
# 26482                            166.0                                   68.0
# 26483                           1450.0                                  518.0
# 26484                             81.0                                   46.0
#
#        Weekday_Monthly_TapOut_AM_Peak Weekend/Hols_Monthly_TapOut_AM_Peak  \
# 0                                 0.0                                 0.0
# 1                              1621.0                               369.0
# 2                              1838.0                               563.0
# 3                                 0.0                               933.0
# 4                              1641.0                               341.0
# ...                               ...                                 ...
# 26480                           370.0                                99.0
# 26481                           444.0                                87.0
# 26482                           279.0                                87.0
# 26483                             0.0                              1925.0
# 26484                           145.0                                26.0
#
#        Weekday_Monthly_TapOut_AM_Offpeak  \
# 0                                    0.0
# 1                                 1184.0
# 2                                 1552.0
# 3                                 1653.0
# 4                                  728.0
# ...                                  ...
# 26480                              340.0
# 26481                              417.0
# 26482                              298.0
# 26483                                0.0
# 26484                              131.0
#
#        Weekend/Hols_Monthly_TapOut_AM_Offpeak  Weekday_Monthly_TapOut_PM_Peak  \
# 0                                         0.0                             0.0
# 1                                       562.0                           979.0
# 2                                       662.0                          1828.0
# 3                                       624.0                          1989.0
# 4                                       226.0                           620.0
# ...                                       ...                             ...
# 26480                                   160.0                           419.0
# 26481                                   204.0                           613.0
# 26482                                   160.0                           392.0
# 26483                                  1919.0                             0.0
# 26484                                    42.0                           160.0
#
#        Weekend/Hols_Monthly_TapOut_PM_Peak  Weekday_Monthly_TapOut_PM_Offpeak  \
# 0                                      0.0                              374.0
# 1                                    482.0                              240.0
# 2                                    652.0                              788.0
# 3                                    797.0                              503.0
# 4                                    196.0                              181.0
# ...                                    ...                                ...
# 26480                                150.0                              170.0
# 26481                                193.0                              235.0
# 26482                                158.0                              114.0
# 26483                               1480.0                              899.0
# 26484                                 56.0                               65.0
#
#        Weekend/Hols_Monthly_TapOut_PM_Offpeak
# 0                                       448.0
# 1                                        84.0
# 2                                       224.0
# 3                                       205.0
# 4                                        72.0
# ...                                       ...
# 26480                                    83.0
# 26481                                   126.0
# 26482                                    52.0
# 26483                                   270.0
# 26484                                    33.0
#
# [26485 rows x 34 columns]

# %%
missing_values = df[df.isnull().any(axis=1)]
similar_routes = df[df['ServiceNo'].isin(missing_values['ServiceNo']) & df['Direction'].isin(missing_values['Direction'])]
display(similar_routes)
# Out:
#       ServiceNo  Direction  StopSequence Operator  BusStopCode  Distance  \
# 365         103          1             1     SBST        66009       0.0
# 366         103          1             2     SBST        62131       0.5
# 367         103          1             3     SBST        62141       0.9
# 368         103          1             4     SBST        63141       1.3
# 369         103          1             5     SBST        63361       1.8
# ...         ...        ...           ...      ...          ...       ...
# 26321       NR6          1            83     SMRT        67399      35.0
# 26322       NR6          1            84     SMRT        67581      35.4
# 26323       NR6          1            85     SMRT        67351      35.7
# 26324       NR6          1            86     SMRT        67341      36.2
# 26325       NR6          1            87     SMRT        67171      36.7
#
#                 RoadName             Description  Latitude   Longitude  ...  \
# 365         S'goon Ave 2              S'Goon Int  1.350466  103.871690  ...
# 366        Upp S'goon Rd       S'Goon Stn Exit H  1.348979  103.872774  ...
# 367        Upp S'goon Rd               Opp Blk 1  1.351491  103.875152  ...
# 368          Boundary Rd                 Blk 209  1.354046  103.874913  ...
# 369    Yio Chu Kang Link  Opp S'Goon Sports Cplx  1.357446  103.873840  ...
# ...                  ...                     ...       ...         ...  ...
# 26321  Sengkang East Way              Blk 325 CP  1.393850  103.891670  ...
# 26322    Anchorvale Link                Blk 319A  1.391042  103.889747  ...
# 26323      Anchorvale Dr              Blk 321 CP  1.389952  103.891344  ...
# 26324     Compassvale Dr          Opp Blk 204 CP  1.388648  103.895052  ...
# 26325     Compassvale Dr                Blk 225A  1.387312  103.898977  ...
#
#       Weekday_Monthly_TapIn_PM_Offpeak  Weekend/Hols_Monthly_TapIn_PM_Offpeak  \
# 365                              967.0                                 1503.0
# 366                             1864.0                                  809.0
# 367                              372.0                                  172.0
# 368                               76.0                                   38.0
# 369                              281.0                                  144.0
# ...                                ...                                    ...
# 26321                            321.0                                  111.0
# 26322                              NaN                                    NaN
# 26323                             21.0                                    8.0
# 26324                             52.0                                   24.0
# 26325                            147.0                                   61.0
#
#        Weekday_Monthly_TapOut_AM_Peak Weekend/Hols_Monthly_TapOut_AM_Peak  \
# 365                            2168.0                               979.0
# 366                            1564.0                               427.0
# 367                             467.0                               181.0
# 368                             141.0                                87.0
# 369                             963.0                               272.0
# ...                               ...                                 ...
# 26321                           712.0                               107.0
# 26322                             NaN                                 NaN
# 26323                           203.0                                28.0
# 26324                           367.0                                59.0
# 26325                           619.0                                77.0
#
#        Weekday_Monthly_TapOut_AM_Offpeak  \
# 365                                  0.0
# 366                               1919.0
# 367                                418.0
# 368                                175.0
# 369                               1340.0
# ...                                  ...
# 26321                              709.0
# 26322                                NaN
# 26323                              266.0
# 26324                              292.0
# 26325                              640.0
#
#        Weekend/Hols_Monthly_TapOut_AM_Offpeak  Weekday_Monthly_TapOut_PM_Peak  \
# 365                                    2276.0                             0.0
# 366                                    1008.0                             0.0
# 367                                     221.0                           563.0
# 368                                     101.0                           351.0
# 369                                     674.0                          2432.0
# ...                                       ...                             ...
# 26321                                   306.0                          1355.0
# 26322                                     NaN                             NaN
# 26323                                   117.0                           498.0
# 26324                                   139.0                           519.0
# 26325                                   298.0                          1440.0
#
#        Weekend/Hols_Monthly_TapOut_PM_Peak  Weekday_Monthly_TapOut_PM_Offpeak  \
# 365                                    0.0                              324.0
# 366                                 1145.0                              704.0
# 367                                  186.0                              220.0
# 368                                   99.0                               92.0
# 369                                  844.0                              949.0
# ...                                    ...                                ...
# 26321                                348.0                              530.0
# 26322                                  NaN                                NaN
# 26323                                140.0                              201.0
# 26324                                176.0                              184.0
# 26325                                429.0                              714.0
#
#        Weekend/Hols_Monthly_TapOut_PM_Offpeak
# 365                                     357.0
# 366                                     302.0
# 367                                      90.0
# 368                                      46.0
# 369                                     455.0
# ...                                       ...
# 26321                                   203.0
# 26322                                     NaN
# 26323                                   100.0
# 26324                                    88.0
# 26325                                   297.0
#
# [3964 rows x 34 columns]

# %%
# Get the mean of the tap in and tap out for the similar routes
similar_routes_mean = similar_routes.groupby(['ServiceNo','Direction']).mean().round()

# Assign the values back to missing values
df.set_index(['ServiceNo','Direction'], inplace=True)
df.fillna(similar_routes_mean, inplace=True)
df.reset_index(inplace=True)
display(df.loc[np.array(missing_values.index)])
# Out:
#       ServiceNo  Direction  StopSequence Operator  BusStopCode  Distance  \
# 404         103          1            40     SBST        59671      17.5
# 1738        122          1            18     SBST        11479       7.2
# 2429        130          2            26     SBST        51041      10.4
# 2668        132          2            24     SBST        51041      10.5
# 3531        141          1            21     SBST        51041       6.8
# ...         ...        ...           ...      ...          ...       ...
# 26160       NR3          1            58     SMRT        45409      27.9
# 26161       NR3          1            59     SMRT        45381      28.1
# 26163       NR3          1            61     SMRT        45479      29.0
# 26236       NR5          1            76     SMRT        22571      29.6
# 26322       NR6          1            84     SMRT        67581      35.4
#
#                   RoadName       Description  Latitude   Longitude  ...  \
# 404           Yishun Ave 2    Bef Yishun Stn  1.427776  103.835187  ...
# 1738           Margaret Dr  The Fisherman Ch  1.299381  103.803720  ...
# 2429            Thomson Rd      Opp SLF Cplx  1.333436  103.837917  ...
# 2668            Thomson Rd      Opp SLF Cplx  1.333436  103.837917  ...
# 3531            Thomson Rd      Opp SLF Cplx  1.333436  103.837917  ...
# ...                    ...               ...       ...         ...  ...
# 26160   Choa Chu Kang Cres           Blk 675  1.401898  103.745796  ...
# 26161  Choa Chu Kang Nth 7  Blk 675A (LP 25)  1.400859  103.747128  ...
# 26163     Choa Chu Kang Dr     Kranji Pr Sch  1.394295  103.746520  ...
# 26236         Boon Lay Way  Opp Boon Lay Stn  1.337804  103.706891  ...
# 26322      Anchorvale Link          Blk 319A  1.391042  103.889747  ...
#
#       Weekday_Monthly_TapIn_PM_Offpeak  Weekend/Hols_Monthly_TapIn_PM_Offpeak  \
# 404                              299.0                                  151.0
# 1738                             291.0                                  183.0
# 2429                             392.0                                  233.0
# 2668                             407.0                                  227.0
# 3531                             339.0                                  177.0
# ...                                ...                                    ...
# 26160                            529.0                                  292.0
# 26161                            529.0                                  292.0
# 26163                            529.0                                  292.0
# 26236                            441.0                                  256.0
# 26322                            560.0                                  403.0
#
#        Weekday_Monthly_TapOut_AM_Peak Weekend/Hols_Monthly_TapOut_AM_Peak  \
# 404                             586.0                               218.0
# 1738                            585.0                               274.0
# 2429                            507.0                               160.0
# 2668                            623.0                               314.0
# 3531                            523.0                               143.0
# ...                               ...                                 ...
# 26160                           448.0                               210.0
# 26161                           448.0                               210.0
# 26163                           448.0                               210.0
# 26236                           737.0                               292.0
# 26322                           716.0                               289.0
#
#        Weekday_Monthly_TapOut_AM_Offpeak  \
# 404                                429.0
# 1738                               559.0
# 2429                               521.0
# 2668                               632.0
# 3531                               526.0
# ...                                  ...
# 26160                              704.0
# 26161                              704.0
# 26163                              704.0
# 26236                              786.0
# 26322                              693.0
#
#        Weekend/Hols_Monthly_TapOut_AM_Offpeak  Weekday_Monthly_TapOut_PM_Peak  \
# 404                                     257.0                           695.0
# 1738                                    357.0                           620.0
# 2429                                    317.0                           531.0
# 2668                                    406.0                           798.0
# 3531                                    261.0                           747.0
# ...                                       ...                             ...
# 26160                                   409.0                           735.0
# 26161                                   409.0                           735.0
# 26163                                   409.0                           735.0
# 26236                                   509.0                           824.0
# 26322                                   582.0                           745.0
#
#        Weekend/Hols_Monthly_TapOut_PM_Peak  Weekday_Monthly_TapOut_PM_Offpeak  \
# 404                                  261.0                              356.0
# 1738                                 343.0                              310.0
# 2429                                 383.0                              288.0
# 2668                                 426.0                              398.0
# 3531                                 311.0                              316.0
# ...                                    ...                                ...
# 26160                                478.0                              386.0
# 26161                                478.0                              386.0
# 26163                                478.0                              386.0
# 26236                                557.0                              488.0
# 26322                                597.0                              450.0
#
#        Weekend/Hols_Monthly_TapOut_PM_Offpeak
# 404                                     150.0
# 1738                                    183.0
# 2429                                    191.0
# 2668                                    185.0
# 3531                                    156.0
# ...                                       ...
# 26160                                   222.0
# 26161                                   222.0
# 26163                                   222.0
# 26236                                   251.0
# 26322                                   274.0
#
# [113 rows x 34 columns]

# %%
# Write back
df.to_csv('data/bus_demand_and_capacity.csv', index=False)

# %% [markdown]
# ## Cleaning for Objective 2
# ### Datasets:
# - Monthly Concession Pass: https://data.gov.sg/dataset/monthly-concession-passes
# - MRT and LRT Fares: https://data.gov.sg/dataset/fare-structure-mrts-and-lrts
# - FEEDER Fares: https://data.gov.sg/dataset/fares-for-feeder-bus-services
# - EXPRESS Fares: https://data.gov.sg/dataset/fare-for-express-bus-services
# - TRUNK Fares: https://data.gov.sg/dataset/fare-structure-for-trunk-bus-services

# %%
mrt_lrt = pd.read_csv('datasrc/mrt_and_lrt_fare.csv')
express = pd.read_csv('datasrc/express_fare.csv')
feeder = pd.read_csv('datasrc/feeder_fare.csv')
trunk = pd.read_csv('datasrc/trunk_fare.csv')
concession_pass = pd.read_csv('datasrc/monthly-concession-pass.csv')

# %%
# Check all datasets for missing values
print(mrt_lrt.isnull().sum())
print(express.isnull().sum())
print(feeder.isnull().sum())
print(trunk.isnull().sum())
print(concession_pass.isnull().sum())
# Out:
# fare_type          0
# applicable_time    0
# distance           0
# fare_per_ride      0
# dtype: int64
# distance                                            0
# cash_fare_per_ride                                  0
# adult_card_fare_per_ride                            0
# senior_citizen_card_fare_per_ride                   0
# student_card_fare_per_ride                          0
# workfare_transport_concession_card_fare_per_ride    0
# persons_with_disabilities_card_fare_per_ride        0
# dtype: int64
# description                                         0
# adult_card_fare_per_ride                            0
# adult_cash_fare_per_ride                            0
# senior_citizen_card_fare_per_ride                   0
# senior_citizen_cash_fare_per_ride                   0
# student_card_fare_per_ride                          0
# student_cash_fare_per_ride                          0
# workfare_transport_concession_card_fare_per_ride    0
# workfare_transport_concession_cash_fare_per_ride    0
# persons_with_disabilities_card_fare_per_ride        0
# persons_with_disabilities_cash_fare_per_ride        0
# dtype: int64
# distance                                            0
# adult_card_fare_per_ride                            0
# adult_cash_fare_per_ride                            0
# senior_citizen_card_fare_per_ride                   0
# senior_citizen_cash_fare_per_ride                   0
# student_card_fare_per_ride                          0
# student_cash_fare_per_ride                          0
# workfare_transport_concession_card_fare_per_ride    0
# workfare_transport_concession_cash_fare_per_ride    0
# persons_with_disabilities_card_fare_per_ride        0
# persons_with_disabilities_cash_fare_per_ride        0
# dtype: int64
# cardholders     0
# bus_price       0
# train_price     0
# hybrid_price    0
# dtype: int64

# %%
# Display all three datasets columns

# Rename columns in EXPRESS
express.rename(columns={'adult_card_fare_per_ride':'express_adult','senior_citizen_card_fare_per_ride':'express_senior_citizen','student_card_fare_per_ride':'express_student','workfare_transport_concession_card_fare_per_ride':'express_workfare','persons_with_disabilities_card_fare_per_ride':'express_disability'}, inplace=True)
# Rename columns in TRUNK
trunk.rename(columns={'adult_card_fare_per_ride':'trunk_adult','senior_citizen_card_fare_per_ride':'trunk_senior_citizen','student_card_fare_per_ride':'trunk_student','workfare_transport_concession_card_fare_per_ride':'trunk_workfare','persons_with_disabilities_card_fare_per_ride':'trunk_disability'}, inplace=True)
# Rename columns in FEEDER
feeder.rename(columns={'adult_card_fare_per_ride':'feeder_adult','senior_citizen_card_fare_per_ride':'feeder_senior_citizen','student_card_fare_per_ride':'feeder_student','workfare_transport_concession_card_fare_per_ride':'feeder_workfare','persons_with_disabilities_card_fare_per_ride':'feeder_disability'}, inplace=True)

bus_fares = pd.merge(express, trunk, on="distance", how="outer")

# Repeat feeder df so that it can combine with bus_fares
feeder = pd.concat([feeder] * len(bus_fares['distance']), ignore_index=True)
feeder['distance'] = bus_fares['distance']
feeder.drop(columns='description', inplace=True)

# Merge all three datasets
bus_fares = pd.merge(bus_fares, feeder, on="distance", how="outer")
# Remove all columns in bus_fares with cash fare using apply
bus_fares = bus_fares[bus_fares.columns.drop(list(bus_fares.filter(regex='cash')))]
print(bus_fares.isnull().sum())
# Out:
# distance                  0
# express_adult             0
# express_senior_citizen    0
# express_student           0
# express_workfare          0
# express_disability        0
# trunk_adult               0
# trunk_senior_citizen      0
# trunk_student             0
# trunk_workfare            0
# trunk_disability          0
# feeder_adult              0
# feeder_senior_citizen     0
# feeder_student            0
# feeder_workfare           0
# feeder_disability         0
# dtype: int64

# %%
display(bus_fares)
# Out:
#              distance  express_adult  express_senior_citizen  express_student  \
# 0        Up to 3.2 km            159                     106               74
# 1     3.3 km - 4.2 km            169                     113               79
# 2     4.3 km - 5.2 km            179                     120               84
# 3     5.3 km - 6.2 km            189                     127               89
# 4     6.3 km - 7.2 km            198                     133               92
# 5     7.3 km - 8.2 km            205                     139               95
# 6     8.3 km - 9.2 km            212                     139               95
# 7    9.3 km - 10.2 km            216                     139               95
# 8   10.3 km - 11.2 km            220                     139               95
# 9   11.3 km - 12.2 km            224                     139               95
# 10  12.3 km - 13.2 km            228                     139               95
# 11  13.3 km - 14.2 km            232                     139               95
# 12  14.3 km - 15.2 km            237                     139               95
# 13  15.3 km - 16.2 km            241                     139               95
# 14  16.3 km - 17.2 km            245                     139               95
# 15  17.3 km - 18.2 km            249                     139               95
# 16  18.3 km - 19.2 km            253                     139               95
# 17  19.3 km - 20.2 km            256                     139               95
# 18  20.3 km - 21.2 km            259                     139               95
# 19  21.3 km - 22.2 km            262                     139               95
# 20  22.3 km - 23.2 km            265                     139               95
# 21  23.3 km - 24.2 km            267                     139               95
# 22  24.3 km - 25.2 km            269                     139               95
# 23  25.3 km - 26.2 km            271                     139               95
# 24  26.3 km - 27.2 km            272                     139               95
# 25  27.3 km - 28.2 km            273                     139               95
# 26  28.3 km - 29.2 km            274                     139               95
# 27  29.3 km - 30.2 km            275                     139               95
# 28  30.3 km - 31.2 km            276                     139               95
# 29  31.3 km - 32.2 km            277                     139               95
# 30  32.3 km - 33.2 km            278                     139               95
# 31  33.3 km - 34.2 km            279                     139               95
# 32  34.3 km - 35.2 km            280                     139               95
# 33  35.3 km - 36.2 km            281                     139               95
# 34  36.3 km - 37.2 km            282                     139               95
# 35  37.3 km - 38.2 km            283                     139               95
# 36  38.3 km - 39.2 km            284                     139               95
# 37  39.3 km - 40.2 km            285                     139               95
# 38       Over 40.2 km            286                     139               95
#
#     express_workfare  express_disability  trunk_adult  trunk_senior_citizen  \
# 0                120                 106           99                    61
# 1                128                 113          109                    68
# 2                136                 120          119                    75
# 3                144                 127          129                    82
# 4                151                 133          138                    88
# 5                157                 139          145                    94
# 6                163                 139          152                    94
# 7                166                 139          156                    94
# 8                169                 139          160                    94
# 9                172                 139          164                    94
# 10               175                 139          168                    94
# 11               178                 139          172                    94
# 12               181                 139          177                    94
# 13               184                 139          181                    94
# 14               187                 139          185                    94
# 15               190                 139          189                    94
# 16               193                 139          193                    94
# 17               196                 139          196                    94
# 18               199                 139          199                    94
# 19               202                 139          202                    94
# 20               205                 139          205                    94
# 21               207                 139          207                    94
# 22               208                 139          209                    94
# 23               209                 139          211                    94
# 24               210                 139          212                    94
# 25               211                 139          213                    94
# 26               212                 139          214                    94
# 27               213                 139          215                    94
# 28               214                 139          216                    94
# 29               215                 139          217                    94
# 30               216                 139          218                    94
# 31               217                 139          219                    94
# 32               218                 139          220                    94
# 33               219                 139          221                    94
# 34               220                 139          222                    94
# 35               221                 139          223                    94
# 36               222                 139          224                    94
# 37               223                 139          225                    94
# 38               224                 139          226                    94
#
#     trunk_student  trunk_workfare  trunk_disability  feeder_adult  \
# 0              44              70                61            99
# 1              49              78                68            99
# 2              54              86                75            99
# 3              59              94                82            99
# 4              62             101                88            99
# 5              65             107                94            99
# 6              65             113                94            99
# 7              65             116                94            99
# 8              65             119                94            99
# 9              65             122                94            99
# 10             65             125                94            99
# 11             65             128                94            99
# 12             65             131                94            99
# 13             65             134                94            99
# 14             65             137                94            99
# 15             65             140                94            99
# 16             65             143                94            99
# 17             65             146                94            99
# 18             65             149                94            99
# 19             65             152                94            99
# 20             65             155                94            99
# 21             65             157                94            99
# 22             65             158                94            99
# 23             65             159                94            99
# 24             65             160                94            99
# 25             65             161                94            99
# 26             65             162                94            99
# 27             65             163                94            99
# 28             65             164                94            99
# 29             65             165                94            99
# 30             65             166                94            99
# 31             65             167                94            99
# 32             65             168                94            99
# 33             65             169                94            99
# 34             65             170                94            99
# 35             65             171                94            99
# 36             65             172                94            99
# 37             65             173                94            99
# 38             65             174                94            99
#
#     feeder_senior_citizen  feeder_student  feeder_workfare  feeder_disability
# 0                      61              44               70                 61
# 1                      61              44               70                 61
# 2                      61              44               70                 61
# 3                      61              44               70                 61
# 4                      61              44               70                 61
# 5                      61              44               70                 61
# 6                      61              44               70                 61
# 7                      61              44               70                 61
# 8                      61              44               70                 61
# 9                      61              44               70                 61
# 10                     61              44               70                 61
# 11                     61              44               70                 61
# 12                     61              44               70                 61
# 13                     61              44               70                 61
# 14                     61              44               70                 61
# 15                     61              44               70                 61
# 16                     61              44               70                 61
# 17                     61              44               70                 61
# 18                     61              44               70                 61
# 19                     61              44               70                 61
# 20                     61              44               70                 61
# 21                     61              44               70                 61
# 22                     61              44               70                 61
# 23                     61              44               70                 61
# 24                     61              44               70                 61
# 25                     61              44               70                 61
# 26                     61              44               70                 61
# 27                     61              44               70                 61
# 28                     61              44               70                 61
# 29                     61              44               70                 61
# 30                     61              44               70                 61
# 31                     61              44               70                 61
# 32                     61              44               70                 61
# 33                     61              44               70                 61
# 34                     61              44               70                 61
# 35                     61              44               70                 61
# 36                     61              44               70                 61
# 37                     61              44               70                 61
# 38                     61              44               70                 61

# %%
# Create a series based on the values of distance (based on the current sort of distance)
# This will later be used for sorting
distance = mrt_lrt['distance'].unique()
mrt_lrt['distance_value'] = mrt_lrt['distance'].apply(lambda x: np.where(distance == x)[0][0])

# Pivot the table to make it similar to bus
mrt_lrt = mrt_lrt.pivot(index=['applicable_time','distance_value','distance'], columns='fare_type', values='fare_per_ride')
mrt_lrt.reset_index(inplace=True)

# Remove the fare_type header
mrt_lrt.columns.name = None

# Rename values in applicable_time
mrt_lrt['applicable_time'] = mrt_lrt['applicable_time'].replace({'All other timings':'After 7.45am', 'Before 7.45am  (Weekdays excluding public holidays)':'Before 7.45am'})
mrt_lrt.rename(columns={'applicable_time':'time', 'Adult card fare': 'adult', 'Persons with diabilities card fare':'disability','Senior citizen card fare':'senior_citizen','Student card fare':'student','Workfare transport concession card fare':'workfare'}, inplace=True)

# Sort values by time then distance
mrt_lrt.sort_values(['time','distance_value'], inplace=True)

mrt_lrt.drop(columns='distance_value',inplace=True)

print(mrt_lrt.isnull().sum())
display(mrt_lrt)
# Out:
# time              0
# distance          0
# adult             0
# disability        0
# senior_citizen    0
# student           0
# workfare          0
# dtype: int64
#              time           distance  adult  disability  senior_citizen  \
# 0    After 7.45am       Up to 3.2 km     99          61              61
# 1    After 7.45am    3.3 km - 4.2 km    109          68              68
# 2    After 7.45am    4.3 km - 5.2 km    119          75              75
# 3    After 7.45am    5.3 km - 6.2 km    129          82              82
# 4    After 7.45am    6.3 km - 7.2 km    138          88              88
# ..            ...                ...    ...         ...             ...
# 73  Before 7.45am  36.3 km - 37.2 km    172          44              44
# 74  Before 7.45am  37.3 km - 38.2 km    173          44              44
# 75  Before 7.45am  38.3 km - 39.2 km    174          44              44
# 76  Before 7.45am  39.3 km - 40.2 km    175          44              44
# 77  Before 7.45am       Over 40.2 km    176          44              44
#
#     student  workfare
# 0        44        70
# 1        49        78
# 2        54        86
# 3        59        94
# 4        62       101
# ..      ...       ...
# 73       15       120
# 74       15       121
# 75       15       122
# 76       15       123
# 77       15       124
#
# [78 rows x 7 columns]

# %%
# Pivot with cardholders being columns
concession_pass = pd.read_csv('datasrc/monthly-concession-pass.csv')
concession_pass = concession_pass.T

# Remove transposed index that is now the first row
concession_pass.reset_index(inplace=True)
# Remove all columns and set first row as new header
concession_pass.columns = concession_pass.iloc[0]
# Remove first row
concession_pass = concession_pass[1:]
display(concession_pass)
# Out:
# 0   cardholders Primary Student Secondary Student Polytechnic Student  \
# 1     bus_price              24                29                  29
# 2   train_price              21              26.5                26.5
# 3  hybrid_price            43.5              54.0                54.0
#
# 0 University Student Full-time National Serviceman Senior Citizen  \
# 1               55.5                          55.5             na
# 2                 48                            48             na
# 3               90.5                          90.5           64.0
#
# 0 Adult (Monthly Travel Pass)
# 1                          na
# 2                          na
# 3                       128.0

# %%
# Write back to csv
mrt_lrt.to_csv('data/mrt_and_lrt_fare.csv', index=False)
bus_fares.to_csv('data/bus_fare.csv', index=False)
concession_pass.to_csv('data/concession_pass.csv', index=False)
